# %% [markdown]
# # Table Extraction Case Study
# ### AAIC Self Case Study II
# ### Author: Soumya De
#
# <hr>
#
# ## 1. Data Collection & Preprocessing
#
# * Dataset - marmot_dataset_v1.0
# * Source - https://www.icst.pku.edu.cn/cpdp/docs/20190424190300041510.zip
#
# We have downloaded the dataset from the above URL as a zip folder and extracted it. Now we will look into the extracted directory to understand how the dataset is organized.

# %%
# importing dependencies
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import struct
from xml.dom import minidom
from xml.etree import ElementTree as eltree
import pandas as pd
from tqdm import tqdm
from shutil import copyfile
from PIL import Image, ImageDraw
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation, Dropout, Layer, UpSampling2D, Conv2DTranspose, Concatenate
from tensorflow.keras.applications import VGG19
import pytesseract

# %%
tf.test.gpu_device_name()
# Out:
# ''

# %%
data_dir = os.path.join('data', 'marmot_dataset_v1.0')
print (data_dir)
# Out:
# data\marmot_dataset_v1.0

# %%
os.listdir(data_dir)
# Out:
# ['copyright.txt',
#  'data',
#  'Layout Description Schema for Marmot.pdf',
#  'xml_schema']

# %% [markdown]
# * The main folder contains some files describing the dataset and a data directory that actually holds the data.

# %%
data_dir = os.path.join(data_dir, 'data')
os.listdir(data_dir)
# Out:
# ['English']

# %% [markdown]
# * Marmot dataset is composed of Chinese and English pages, which is kept is separate folders. Lets have a look into each of these.

# %%
#print(os.listdir(os.path.join(data_dir, 'Chinese')))
print(os.listdir(os.path.join(data_dir, 'English')))
# Out:
# ['Negative', 'Positive']

# %% [markdown]
# * Okay, both of these folders have same subdirectory structure, consisting folders named positive and negative.
# * For the sake of simplicity, we will consider only the English folder now and explore it further.
# * Later on, we can check what's inside the chinese directory.

# %%
# exploring the english subdirectory
english_data_dir = os.path.join(data_dir, 'English')
print('Contents of the English subdirectory : ')
print(os.listdir(english_data_dir))
print()
print('Contents of the positive subdirectory : ')
print(os.listdir(os.path.join(english_data_dir, 'positive')))
print()
print('Contents of the negative subdirectory : ')
print(os.listdir(os.path.join(english_data_dir, 'negative')))
# Out:
# Contents of the English subdirectory :
# ['Negative', 'Positive']
#
# Contents of the positive subdirectory :
# ['Labeled', 'Raw']
#
# Contents of the negative subdirectory :
# ['Labeled', 'Raw']

# %% [markdown]
# * We can see that the positive and negative directories have also similar contents
# * There are two folders namely Labeled and Raw, in both positive and negative directories.

# %% [markdown]
# #### * Positive

# %%
print("Number of files in Positive/Raw : ", len(os.listdir(os.path.join(english_data_dir, 'Positive', 'Raw'))))
print()
print("Some contents of the Positive/Raw directory :")
os.listdir(os.path.join(english_data_dir, 'Positive', 'Raw'))[:10]
# Out:
# Number of files in Positive/Raw :  200
#
# Some contents of the Positive/Raw directory :
# ['10.1.1.1.2006_3.bmp',
#  '10.1.1.1.2006_3_phy.xml',
#  '10.1.1.1.2010_5.bmp',
#  '10.1.1.1.2010_5_phy.xml',
#  '10.1.1.1.2013_63.bmp',
#  '10.1.1.1.2013_63_phy.xml',
#  '10.1.1.1.2013_64.bmp',
#  '10.1.1.1.2013_64_phy.xml',
#  '10.1.1.1.2014_4.bmp',
#  '10.1.1.1.2014_4_phy.xml']

# %%
bmp_files = [f for f in os.listdir(os.path.join(english_data_dir, 'Positive', 'Raw')) if f.endswith('bmp')]
xml_raw_files = [f for f in os.listdir(os.path.join(english_data_dir, 'Positive', 'Raw')) if f.endswith('xml')]
print("Number of .bmp files (Positive): ", len(bmp_files))
print("Number of raw .xml files (Positive) : ", len(xml_raw_files))
# Out:
# Number of .bmp files (Positive):  100
# Number of raw .xml files (Positive) :  100

# %%
print("Number of files in Positive/Labeled : ", len(os.listdir(os.path.join(english_data_dir, 'Positive', 'Labeled'))))
print()
print("Some contents of the Positive/Labeled directory :")
os.listdir(os.path.join(english_data_dir, 'Positive', 'Labeled'))[:10]
# Out:
# Number of files in Positive/Labeled :  100
#
# Some contents of the Positive/Labeled directory :
# ['10.1.1.1.2006_3.xml',
#  '10.1.1.1.2010_5.xml',
#  '10.1.1.1.2013_63.xml',
#  '10.1.1.1.2013_64.xml',
#  '10.1.1.1.2014_4.xml',
#  '10.1.1.1.2014_6.xml',
#  '10.1.1.1.2018_4.xml',
#  '10.1.1.1.2018_8.xml',
#  '10.1.1.1.2019_2.xml',
#  '10.1.1.1.2019_3.xml']

# %%
# checking a random positive .bmp file

r = np.random.randint(len(bmp_files))
#np.- NumPy can be used to perform a wide variety of mathematical operations on arrays.

img_filepath = os.path.join(english_data_dir, 'Positive', 'Raw', bmp_files[r])
print(img_filepath)
# Out:
# data\marmot_dataset_v1.0\data\English\Positive\Raw\10.1.1.1.2013_64.bmp

# %%
img = cv2.imread(img_filepath, cv2.IMREAD_UNCHANGED)
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
#cv2.imshow('image', img)

# %%
#Figure instance and an Axes inside the Figure object.
plt.figure(figsize=(20,10))
plt.show()

# %%
plt.axis('off')
plt.show()

# %%
plt.title(bmp_files[r])
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
# checking the corresponding .xml annotation
# Ref: https://stackabuse.com/reading-and-writing-xml-files-in-python/
# Ref: https://stackoverflow.com/questions/52824584/do-anyone-know-how-to-extract-image-coordinate-from-marmot-dataset

def hex2double(hexcode):
    """
    This function takes a 16 digit hexadecimal representation and
    convert it into its equivalent floating point form
    """
    return struct.unpack('!d', bytes.fromhex(hexcode))[0]

# %%
xml_fpath = img_filepath.replace('Raw', 'Labeled').replace('bmp', 'xml')
print(xml_fpath)
# Out:
# data\marmot_dataset_v1.0\data\English\Positive\Labeled\10.1.1.1.2013_64.xml

# %%
xml_file = eltree.parse(xml_fpath)
#????allows you to parse and navigate an XML document????
print(xml_file)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x000001EE0FBEA460>

# %%
root = xml_file.getroot()
print(root)
# Out:
# <Element 'Page' at 0x000001EE407942C0>

# %%
left, bottom, right, top = (hex2double(i) for i in root.get('CropBox').split())
pa_width = np.abs(left - right)
pa_height = np.abs(top - bottom)

bounding_boxes = []

height, width, _ = img.shape


print("left: ", left, " right: ", right, " top: ", top, " bottom: ", bottom, " pa_width: ", pa_width, " pa_height: ", pa_height
     ," height: ", height, " width: ", width)
# Out:
# left:  0.0  right:  612.0  top:  0.0  bottom:  792.0  pa_width:  612.0  pa_height:  792.0  height:  1056  width:  816

# %%
for each_table_comp in xml_file.findall(".//Composite[@Label='Table']"):
    t_left, t_bottom, t_right, t_top = [hex2double(i) for i in each_table_comp.get('BBox').split()]
    print("t_left: ", t_left, " t_right: ", t_right, " t_top: ", t_top, " t_bottom: ", t_bottom)
# Out:
# t_left:  88.08  t_right:  521.5200000000001  t_top:  303.84  t_bottom:  513.0928125
# t_left:  88.08  t_right:  521.52  t_top:  544.56  t_bottom:  678.4528125

# %%
    t_left = width/pa_width * np.abs(t_left - left) 
    print(t_left)
    t_right = width/pa_width * np.abs(t_right - left)
    t_bottom = height/pa_height * np.abs(t_bottom - bottom) 
    t_top = height/pa_height * np.abs(t_top - bottom)
    
    #understand the equation???????????????
    
    print("t_left: ", t_left, " t_right: ", t_right, " t_top: ", t_top, " t_bottom: ", t_bottom)
# Out:
# 117.44
# t_left:  117.44  t_right:  695.3599999999999  t_top:  329.9200000000001  t_bottom:  151.39624999999992

# %%
bounding_boxes=[]

# %%
bounding_boxes.append([t_left, t_top, t_right, t_bottom])

# %%
def crop_table(image_path, list_of_bboxes):
    fig = plt.figure(figsize=(20,10))
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    i = 1
    for each_bbox in list_of_bboxes:
        ax = fig.add_subplot(len(list_of_bboxes), 1, i)
        left, top, right, bottom = (int(i) for i in each_bbox)
        table_image = image[bottom:top, left:right]
        plt.axis('off')
        plt.imshow(table_image)
        i = i+1
    return None

# %%
crop_table(img_filepath, bounding_boxes)

# %% [markdown]
# * Therefore, with help of above code snippet we can fetch the bounding boxes for all all the tables in an given image, in the marmot_dataset_v1.0
# * There is another version of this dataset available, annotated by the TableNet team (Paliwal et al.), that  gives the column level bounding boxes.
#
# Source : https://drive.google.com/drive/folders/1QZiv5RKe3xlOBdTzuTVuYRxixemVIODp
#
# We have downloaded the dataset from the above URL (zip folder) and extracted it. Take a look at the data.

# %%
data_dir = os.path.join('data', 'marmot_extended')
print("Total number of files in the directory : ", len(os.listdir(data_dir)))
print("Few contents of the directory : ")
os.listdir(data_dir)[0:5]
# Out:
# Total number of files in the directory :  198
# Few contents of the directory :
# ['10.1.1.1.2006_3.bmp',
#  '10.1.1.1.2006_3.xml',
#  '10.1.1.1.2010_5.bmp',
#  '10.1.1.1.2013_63.bmp',
#  '10.1.1.1.2013_63.xml']

# %%
bmp_files = [i for i in os.listdir(data_dir) if i.endswith('bmp')]
xml_files = [i for i in os.listdir(data_dir) if i.endswith('xml')]
print("Number of .bmp files : ", len(bmp_files))
print("Number of .xml files : ", len(xml_files))
# Out:
# Number of .bmp files :  100
# Number of .xml files :  98

# %% [markdown]
# * These annotations contains the bounding box for each columns of the tables.
# * This dataset only contains the images from the English/Positive subfolder of the original dataset.
# * The number of annotation files is 495 whereas there are 509 bitmap images. Hence 14 xml files of corresponding images are not present.
# * We have seen a typical image data in the marmot dataset before, lets check only the layout the new annotation files

# %%
# random .xml file in the marmot_extended
r = np.random.randint(len(xml_files))

print(r)
# Out:
# 77

# %%
xml_file_path = os.path.join(data_dir, xml_files[r])
xml_file = eltree.parse(xml_file_path)
print(xml_file)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x000001EE0FBD44C0>

# %%
# trying to retrive image dimension
rt = xml_file.getroot()
int(rt.findall('size')[0].findall('width')[0].text), int(rt.findall('size')[0].findall('height')[0].text)
# Out:
# (793, 1123)

# %%
# checking the name of annotated objects
for ele in rt.findall('object'):
    print(ele.find('name').text)
# Out:
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column
# column

# %% [markdown]
# * These new annotations only consists of bounding boxes for each column present in the image.
# * The annotations in marmot_dataset_v1.0 contains only table annotations
# * We will use these two type of annotations and create mask w.r.t. each image present in the dataset.
# * Since the column level annotations are missing for 14 datapoints, we will also ignone the 14 table level annotations

# %%
# This function will take a list of file names (images) and create table mask and column mask for each file and store the image paths and dimension in a dataframe

def hex2double(hexcode):
    """
    Input: 16digit hexadecimal number
    Output: Equivalent floating point representation
    """
    return struct.unpack('!d', bytes.fromhex(hexcode))[0]


def return_bboxes_extended(xml):
    """
    Input: Annotated xml file of an image from the marmot extended dataset
    Output: Dimension of the image and the list of bounding boxes of table columns present in the image
    """
    xml_file = eltree.parse(xml)
    root = xml_file.getroot()
    bboxes = []
    width = int(rt.findall('size')[0].findall('width')[0].text)
    height = int(rt.findall('size')[0].findall('height')[0].text)
    for ele in root.findall('object'):
        if ele.find('name').text == 'column':
            bbox = ele.find('bndbox')
            left = int(bbox.find('xmin').text)
            right = int(bbox.find('xmax').text)
            top = int(bbox.find('ymin').text)
            bottom = int(bbox.find('ymax').text)
        bboxes.append([left, top, right, bottom])
    return width, height, bboxes


def return_bboxes_v1(xml, width, height):
    """
    Input: Annotated xml file of an image from the marmot v1.0 dataset
    Output: The list of bounding boxes of tables present in the image
    """
    xml_file = eltree.parse(xml)
    root = xml_file.getroot()
    left, bottom, right, top = (hex2double(i) for i in root.get('CropBox').split())
    pa_width = np.abs(left - right)
    pa_height = np.abs(top - bottom)
    bboxes = []
    for each_table_comp in xml_file.findall(".//Composite[@Label='Table']"):
        t_left, t_bottom, t_right, t_top = [hex2double(i) for i in each_table_comp.get('BBox').split()]
        t_left = int(width/pa_width * np.abs(t_left - left))
        t_right = int(width/pa_width * np.abs(t_right - left))
        t_bottom = int(height/pa_height * np.abs(t_bottom - bottom)) 
        t_top = int(height/pa_height * np.abs(t_top - bottom))
        bboxes.append([t_left, t_top, t_right, t_bottom])
    return bboxes


def create_mask(img_path, list_of_bboxes, dim, mode='table'):
    """
    Input: Image, its corresponding list of bounding boxes, dimension of the image 
    and mode specifying the annotation type (table/column)
    Output: Create corresponding mask image (containing the boxes) and return the mask file path
    """
    data_dir = os.path.join('data', 'marmot_masked')
    image_dir = os.path.join(data_dir, 'images')
    mask_dir = os.path.join(data_dir, 'masks', mode)
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    if not os.path.exists(image_dir):
        os.makedirs(image_dir)
    if not os.path.exists(mask_dir):
        os.makedirs(mask_dir)
    fname = img_path.split(os.path.sep)[-1].replace('bmp', 'png')
    dest = os.path.join(image_dir, fname)
    if mode == 'table':
        img = Image.open(img_path)
        img.save(dest, 'png')
    image = Image.new("RGB", dim)
    mask = ImageDraw.Draw(image)
    for each_list in list_of_bboxes:
        mask.rectangle(each_list, fill=255)
    mask_fn = os.path.join(mask_dir, fname)
    image = np.array(image)
    image = Image.fromarray(image[:,:,0])
    image.save(mask_fn)
    if mode == 'table':
        return dest, mask_fn  
    return mask_fn


def compute_masks():
    """
    Returns a pandas dataframe containing the imagepath and mask_path and dimension.
    It invokes the above two methods to create corresponding mask images
    """
    images_dir = os.path.join('data', 'marmot_extended')
    img_file_list = [i for i in os.listdir(images_dir) if i.endswith('bmp')]
    img_df = pd.DataFrame(columns=['image_path', 'image_dim', 'tablemask_path', 'columnmask_path'])
    #count=0
    for each_image in tqdm(img_file_list):
        #count = count +1
        img_path = os.path.join(images_dir, each_image)
        table_annot = os.path.join('data', 'marmot_dataset_v1.0', 'data', 'English', 'Positive', 'Labeled', each_image.replace('bmp', 'xml'))
        column_annot = img_path.replace('bmp', 'xml')
        if not os.path.exists(column_annot):
            continue
        width, height, column_bboxes = return_bboxes_extended(column_annot)
        dim = (width, height)
        table_bboxes = return_bboxes_v1(table_annot, width, height)
        image_path, table_mask_path = create_mask(img_path, table_bboxes, dim, mode='table')
        column_mask_path = create_mask(img_path, column_bboxes, dim, mode='column')
        img_df.loc[len(img_df.index)] = [image_path, dim, table_mask_path, column_mask_path]
        csv_fname = os.path.join('data', 'marmot_masked', 'data.csv')
#         if count==1:
#             print(img_df)
        img_df.to_csv(csv_fname, index=False)
    print(img_df)
    return img_df

# %%
img_df = compute_masks()
# Out:
# 100%|██████████| 100/100 [00:12<00:00,  8.31it/s]
#                                         image_path    image_dim  \
# 0    data\marmot_masked\images\10.1.1.1.2006_3.png  (793, 1123)
# 1   data\marmot_masked\images\10.1.1.1.2013_63.png  (793, 1123)
# 2   data\marmot_masked\images\10.1.1.1.2013_64.png  (793, 1123)
# 3    data\marmot_masked\images\10.1.1.1.2014_4.png  (793, 1123)
# 4    data\marmot_masked\images\10.1.1.1.2014_6.png  (793, 1123)
# ..                                             ...          ...
# 92   data\marmot_masked\images\10.1.1.6.2223_6.png  (793, 1123)
# 93  data\marmot_masked\images\10.1.1.6.2234_17.png  (793, 1123)
# 94   data\marmot_masked\images\10.1.1.6.2234_6.png  (793, 1123)
# 95   data\marmot_masked\images\10.1.1.6.2243_7.png  (793, 1123)
# 96   data\marmot_masked\images\10.1.1.6.2248_9.png  (793, 1123)
#
#                                        tablemask_path  \
# 0   data\marmot_masked\masks\table\10.1.1.1.2006_3...
# 1   data\marmot_masked\masks\table\10.1.1.1.2013_6...
# 2   data\marmot_masked\masks\table\10.1.1.1.2013_6...
# 3   data\marmot_masked\masks\table\10.1.1.1.2014_4...
# 4   data\marmot_masked\masks\table\10.1.1.1.2014_6...
# ..                                                ...
# 92  data\marmot_masked\masks\table\10.1.1.6.2223_6...
# 93  data\marmot_masked\masks\table\10.1.1.6.2234_1...
# 94  data\marmot_masked\masks\table\10.1.1.6.2234_6...
# 95  data\marmot_masked\masks\table\10.1.1.6.2243_7...
# 96  data\marmot_masked\masks\table\10.1.1.6.2248_9...
#
#                                       columnmask_path
# 0   data\marmot_masked\masks\column\10.1.1.1.2006_...
# 1   data\marmot_masked\masks\column\10.1.1.1.2013_...
# 2   data\marmot_masked\masks\column\10.1.1.1.2013_...
# 3   data\marmot_masked\masks\column\10.1.1.1.2014_...
# 4   data\marmot_masked\masks\column\10.1.1.1.2014_...
# ..                                                ...
# 92  data\marmot_masked\masks\column\10.1.1.6.2223_...
# 93  data\marmot_masked\masks\column\10.1.1.6.2234_...
# 94  data\marmot_masked\masks\column\10.1.1.6.2234_...
# 95  data\marmot_masked\masks\column\10.1.1.6.2243_...
# 96  data\marmot_masked\masks\column\10.1.1.6.2248_...
#
# [97 rows x 4 columns]

# %% [markdown]
# * We created the table and column mask w.r.t. each image
# * We will now analyze the distribution of widths and heights

# %%
width_list = [i[0] for i in img_df['image_dim'].values]
height_list = [i[1] for i in img_df['image_dim'].values]

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.hist(width_list)
plt.title('width dist. of images')
plt.subplot(1,2,2)
plt.hist(height_list)
plt.title('height dist. of images')
plt.show()

# %% [markdown]
# * All images in the dataset are of width and height i.e., (816, 1056)
# * There are only 494 images with table and column level bounding box annotations
# * We will now check another similar dataset ICDAR 2017
#
#
# <hr>
#
# * Dataset - ICDAR 2017
# * Source - https://github.com/mawanda-jun/TableTrainNet/tree/master/dataset

# %%
data_dir = os.path.join('data', 'ICDAR 2017')

# %%
os.listdir(data_dir)
# Out:
# ['Annotations',
#  'common_func.py',
#  'data.csv',
#  'data_structure.py',
#  'draw_img.py',
#  'generate_database_csv.py',
#  'Images',
#  'img_to_jpeg.py',
#  'TableTrainNet',
#  'table_images',
#  'table_masks']

# %%
print('Number of images : ', len(os.listdir(os.path.join(data_dir, 'Images'))))
print('Number of annotation files : ', len(os.listdir(os.path.join(data_dir, 'Annotations'))))
# Out:
# Number of images :  101
# Number of annotation files :  101

# %% [markdown]
# * There are total 1600 images and annotations in the ICDAR 2017 dataset.
# * We now look at a random image and annotation from it.

# %%
bmp_files = os.listdir(os.path.join(data_dir, 'Images'))

r = np.random.randint(len(bmp_files))

print(r)
# Out:
# 18

# %%
img_filepath = os.path.join(data_dir, 'Images', bmp_files[r])
img = cv2.imread(img_filepath, cv2.IMREAD_UNCHANGED)
plt.figure(figsize=(20,10))
plt.axis('off')
plt.title(bmp_files[r])
plt.imshow(img)
plt.show()

# %% [markdown]
# * All the images in the dataset doesn't mandatorily contains a table since dataset was designed for recognition for various objects like formula, figure etc. along with table

# %%
xml_files = os.listdir(os.path.join(data_dir, 'Annotations'))

xml_file_path = os.path.join(data_dir, 'Annotations', xml_files[r])
xml_file = minidom.parse(xml_file_path)
print(xml_file.toprettyxml())
# Out:
# <?xml version="1.0" ?>
# <document filename="POD_0018.xml">
#
#
# 	<formulaRegion>
#
#
# 		<Coords points="416,401 908,401 416,449 908,449"/>
#
#
# 	</formulaRegion>
#
#
# 	<formulaRegion>
#
#
# 		<Coords points="398,535 908,535 398,584 908,584"/>
#
#
# 	</formulaRegion>
#
#
# 	<formulaRegion>
#
#
# 		<Coords points="461,771 572,771 461,792 572,792"/>
#
#
# 	</formulaRegion>
#
#
# </document>

# %% [markdown]
# * But we can check if a table is present in an image and get its bounding box from the corresponding annotation file. The annotation files contain tags called <tableRegion> with bounding box information if a table is present in the corresponding image.
#
# * Therefore, we will consider the images with tables only and  create masked images for those images in the dataset as we have done in the previous section for the marmot data.

# %%
def create_mask(img_path, list_of_bboxes, dim):
    """
    Input: takes a image path and list of bounding boxes to create corresponding mask image
    for ICDAR 2017 data
    Output: returns the file name of the mask file
    """
    data_dir = os.path.join('data', 'ICDAR 2017')
    image_dir = os.path.join(data_dir, 'table_images')
    mask_dir = os.path.join(data_dir, 'table_masks')
    print("data_dir = ", data_dir , " image_dir = ", image_dir , " mask_dir = ", mask_dir)
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    if not os.path.exists(image_dir):
        os.makedirs(image_dir)
    if not os.path.exists(mask_dir):
        os.makedirs(mask_dir)
    fname = img_path.split(os.path.sep)[-1].replace('bmp', 'png')
    dest = os.path.join(image_dir, fname)
    print("fname = ", fname , " dest = ", dest)
    img = Image.open(img_path)
    img.save(dest, 'png')
    image = Image.new("RGB", dim)
    mask = ImageDraw.Draw(image)
    for each_list in list_of_bboxes:
        mask.rectangle(each_list, fill=255)
    mask_fn = os.path.join(mask_dir, fname)
    print("mask_fn = ", mask_fn )
    image = np.array(image)
    image = Image.fromarray(image[:,:,0])
    image.save(mask_fn) 
    return mask_fn


def compute_masks():
    """
    Returns a pandas dataframe containing the imagepath and mask_path and dimension.
    It invokes the above method to create corresponding mask images
    """
    img_df = pd.DataFrame(columns=['image_path', 'image_dim', 'mask_path'])
    images_dir = os.path.join('data', 'ICDAR 2017', 'Images')
    annots_dir = os.path.join('data', 'ICDAR 2017', 'Annotations')
    xml_filelist = os.listdir(annots_dir)
    for each_xml in tqdm(xml_filelist):
        xml_path = os.path.join(annots_dir, each_xml)
        xml = eltree.parse(xml_path)
        root = xml.getroot()
        table_list = root.findall('tableRegion')
        if len(table_list)==0:
            continue
        else:
            vertex_list = []
            for each_table in table_list:
                cord_list = each_table.find('Coords').get('points')
                cord_list = cord_list.split()
                vertices = [tuple(int(i) for i in cord_list[0].split(',')), tuple(int(i) for i in cord_list[-1].split(','))]
                vertex_list.append(vertices)
            image_path = xml_path.replace('Annotations', 'Images').replace('xml', 'bmp')
            image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
            height, width, _ = image.shape
            mask_path = create_mask(image_path, vertex_list, (width, height))

            img_df.loc[len(img_df.index)] = [image_path, (width, height), mask_path]
        csv_fname = os.path.join('data', 'ICDAR 2017', 'data.csv')
    img_df.to_csv(csv_fname, index=False)
    print(img_df)
    return img_df

# %%
img_df = compute_masks()
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0001.png  dest =  data\ICDAR 2017\table_images\POD_0001.png
#   2%|▏         | 2/101 [00:00<00:08, 12.20it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0001.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0003.png  dest =  data\ICDAR 2017\table_images\POD_0003.png
#   4%|▍         | 4/101 [00:00<00:13,  7.41it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0003.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0004.png  dest =  data\ICDAR 2017\table_images\POD_0004.png
#   8%|▊         | 8/101 [00:00<00:08, 10.35it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0004.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0007.png  dest =  data\ICDAR 2017\table_images\POD_0007.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0007.png
#  12%|█▏        | 12/101 [00:00<00:05, 15.48it/s]
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0011.png  dest =  data\ICDAR 2017\table_images\POD_0011.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0011.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0014.png  dest =  data\ICDAR 2017\table_images\POD_0014.png
#  18%|█▊        | 18/101 [00:01<00:04, 17.90it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0014.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0017.png  dest =  data\ICDAR 2017\table_images\POD_0017.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0017.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0021.png  dest =  data\ICDAR 2017\table_images\POD_0021.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0021.png
#  24%|██▍       | 24/101 [00:01<00:05, 13.41it/s]
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0022.png  dest =  data\ICDAR 2017\table_images\POD_0022.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0022.png
#  26%|██▌       | 26/101 [00:01<00:05, 13.33it/s]
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0024.png  dest =  data\ICDAR 2017\table_images\POD_0024.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0024.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0026.png  dest =  data\ICDAR 2017\table_images\POD_0026.png
#  31%|███       | 31/101 [00:02<00:04, 16.16it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0026.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0030.png  dest =  data\ICDAR 2017\table_images\POD_0030.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0030.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0031.png  dest =  data\ICDAR 2017\table_images\POD_0031.png
#  37%|███▋      | 37/101 [00:02<00:03, 19.34it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0031.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0036.png  dest =  data\ICDAR 2017\table_images\POD_0036.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0036.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0038.png  dest =  data\ICDAR 2017\table_images\POD_0038.png
#  43%|████▎     | 43/101 [00:02<00:02, 20.08it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0038.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0040.png  dest =  data\ICDAR 2017\table_images\POD_0040.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0040.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
#  46%|████▌     | 46/101 [00:02<00:02, 21.50it/s]
# fname =  POD_0045.png  dest =  data\ICDAR 2017\table_images\POD_0045.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0045.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0048.png  dest =  data\ICDAR 2017\table_images\POD_0048.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0048.png
#  51%|█████▏    | 52/101 [00:03<00:02, 23.15it/s]
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0051.png  dest =  data\ICDAR 2017\table_images\POD_0051.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0051.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0053.png  dest =  data\ICDAR 2017\table_images\POD_0053.png
#  57%|█████▋    | 58/101 [00:03<00:01, 22.78it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0053.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0055.png  dest =  data\ICDAR 2017\table_images\POD_0055.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0055.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0060.png  dest =  data\ICDAR 2017\table_images\POD_0060.png
#  60%|██████    | 61/101 [00:03<00:02, 16.35it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0060.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0063.png  dest =  data\ICDAR 2017\table_images\POD_0063.png
#  65%|██████▌   | 66/101 [00:04<00:02, 14.28it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0063.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0064.png  dest =  data\ICDAR 2017\table_images\POD_0064.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0064.png
#  67%|██████▋   | 68/101 [00:04<00:02, 14.19it/s]
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0067.png  dest =  data\ICDAR 2017\table_images\POD_0067.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0067.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0077.png  dest =  data\ICDAR 2017\table_images\POD_0077.png
#  77%|███████▋  | 78/101 [00:04<00:00, 27.77it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0077.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0078.png  dest =  data\ICDAR 2017\table_images\POD_0078.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0078.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0079.png  dest =  data\ICDAR 2017\table_images\POD_0079.png
#  83%|████████▎ | 84/101 [00:04<00:00, 21.51it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0079.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0083.png  dest =  data\ICDAR 2017\table_images\POD_0083.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0083.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0085.png  dest =  data\ICDAR 2017\table_images\POD_0085.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0085.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0086.png  dest =  data\ICDAR 2017\table_images\POD_0086.png
#  90%|█████████ | 91/101 [00:05<00:00, 19.90it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0086.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0090.png  dest =  data\ICDAR 2017\table_images\POD_0090.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0090.png
# data_dir =
#  93%|█████████▎| 94/101 [00:05<00:00, 20.48it/s]
# data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0092.png  dest =  data\ICDAR 2017\table_images\POD_0092.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0092.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0094.png  dest =  data\ICDAR 2017\table_images\POD_0094.png
#  96%|█████████▌| 97/101 [00:05<00:00, 21.53it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0094.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0098.png  dest =  data\ICDAR 2017\table_images\POD_0098.png
# mask_fn =  data\ICDAR 2017\table_masks\POD_0098.png
# data_dir =  data\ICDAR 2017  image_dir =  data\ICDAR 2017\table_images  mask_dir =  data\ICDAR 2017\table_masks
# fname =  POD_0099.png  dest =  data\ICDAR 2017\table_images\POD_0099.png
# 100%|██████████| 101/101 [00:05<00:00, 17.58it/s]
# mask_fn =  data\ICDAR 2017\table_masks\POD_0099.png
#                              image_path     image_dim  \
# 0   data\ICDAR 2017\Images\POD_0001.bmp  (1061, 1373)
# 1   data\ICDAR 2017\Images\POD_0003.bmp  (1061, 1373)
# 2   data\ICDAR 2017\Images\POD_0004.bmp  (1061, 1373)
# 3   data\ICDAR 2017\Images\POD_0007.bmp  (1061, 1373)
# 4   data\ICDAR 2017\Images\POD_0011.bmp  (1031, 1459)
# 5   data\ICDAR 2017\Images\POD_0014.bmp  (1061, 1373)
# 6   data\ICDAR 2017\Images\POD_0017.bmp  (1031, 1459)
# 7   data\ICDAR 2017\Images\POD_0021.bmp  (1061, 1373)
# 8   data\ICDAR 2017\Images\POD_0022.bmp  (1061, 1373)
# 9   data\ICDAR 2017\Images\POD_0024.bmp  (1061, 1373)
# 10  data\ICDAR 2017\Images\POD_0026.bmp   (835, 1189)
# 11  data\ICDAR 2017\Images\POD_0030.bmp  (1061, 1373)
# 12  data\ICDAR 2017\Images\POD_0031.bmp  (1061, 1373)
# 13  data\ICDAR 2017\Images\POD_0036.bmp  (1031, 1459)
# 14  data\ICDAR 2017\Images\POD_0038.bmp  (1031, 1459)
# 15  data\ICDAR 2017\Images\POD_0040.bmp  (1031, 1459)
# 16  data\ICDAR 2017\Images\POD_0045.bmp  (1031, 1459)
# 17  data\ICDAR 2017\Images\POD_0048.bmp  (1373, 1061)
# 18  data\ICDAR 2017\Images\POD_0051.bmp  (1061, 1373)
# 19  data\ICDAR 2017\Images\POD_0053.bmp  (1061, 1373)
# 20  data\ICDAR 2017\Images\POD_0055.bmp  (1031, 1459)
# 21  data\ICDAR 2017\Images\POD_0060.bmp  (1061, 1373)
# 22  data\ICDAR 2017\Images\POD_0063.bmp  (1061, 1373)
# 23  data\ICDAR 2017\Images\POD_0064.bmp  (1061, 1373)
# 24  data\ICDAR 2017\Images\POD_0067.bmp  (1030, 1373)
# 25  data\ICDAR 2017\Images\POD_0077.bmp  (1061, 1373)
# 26  data\ICDAR 2017\Images\POD_0078.bmp  (1061, 1459)
# 27  data\ICDAR 2017\Images\POD_0079.bmp  (1061, 1373)
# 28  data\ICDAR 2017\Images\POD_0083.bmp  (1031, 1459)
# 29  data\ICDAR 2017\Images\POD_0085.bmp  (1031, 1459)
# 30  data\ICDAR 2017\Images\POD_0086.bmp  (1061, 1373)
# 31  data\ICDAR 2017\Images\POD_0090.bmp  (1061, 1373)
# 32  data\ICDAR 2017\Images\POD_0092.bmp  (1061, 1373)
# 33  data\ICDAR 2017\Images\POD_0094.bmp  (1032, 1459)
# 34  data\ICDAR 2017\Images\POD_0098.bmp  (1032, 1459)
# 35  data\ICDAR 2017\Images\POD_0099.bmp  (1061, 1373)
#
#                                    mask_path
# 0   data\ICDAR 2017\table_masks\POD_0001.png
# 1   data\ICDAR 2017\table_masks\POD_0003.png
# 2   data\ICDAR 2017\table_masks\POD_0004.png
# 3   data\ICDAR 2017\table_masks\POD_0007.png
# 4   data\ICDAR 2017\table_masks\POD_0011.png
# 5   data\ICDAR 2017\table_masks\POD_0014.png
# 6   data\ICDAR 2017\table_masks\POD_0017.png
# 7   data\ICDAR 2017\table_masks\POD_0021.png
# 8   data\ICDAR 2017\table_masks\POD_0022.png
# 9   data\ICDAR 2017\table_masks\POD_0024.png
# 10  data\ICDAR 2017\table_masks\POD_0026.png
# 11  data\ICDAR 2017\table_masks\POD_0030.png
# 12  data\ICDAR 2017\table_masks\POD_0031.png
# 13  data\ICDAR 2017\table_masks\POD_0036.png
# 14  data\ICDAR 2017\table_masks\POD_0038.png
# 15  data\ICDAR 2017\table_masks\POD_0040.png
# 16  data\ICDAR 2017\table_masks\POD_0045.png
# 17  data\ICDAR 2017\table_masks\POD_0048.png
# 18  data\ICDAR 2017\table_masks\POD_0051.png
# 19  data\ICDAR 2017\table_masks\POD_0053.png
# 20  data\ICDAR 2017\table_masks\POD_0055.png
# 21  data\ICDAR 2017\table_masks\POD_0060.png
# 22  data\ICDAR 2017\table_masks\POD_0063.png
# 23  data\ICDAR 2017\table_masks\POD_0064.png
# 24  data\ICDAR 2017\table_masks\POD_0067.png
# 25  data\ICDAR 2017\table_masks\POD_0077.png
# 26  data\ICDAR 2017\table_masks\POD_0078.png
# 27  data\ICDAR 2017\table_masks\POD_0079.png
# 28  data\ICDAR 2017\table_masks\POD_0083.png
# 29  data\ICDAR 2017\table_masks\POD_0085.png
# 30  data\ICDAR 2017\table_masks\POD_0086.png
# 31  data\ICDAR 2017\table_masks\POD_0090.png
# 32  data\ICDAR 2017\table_masks\POD_0092.png
# 33  data\ICDAR 2017\table_masks\POD_0094.png
# 34  data\ICDAR 2017\table_masks\POD_0098.png
# 35  data\ICDAR 2017\table_masks\POD_0099.png

# %% [markdown]
# * We created the table mask w.r.t. the images containing table
# * We will now analyze the distribution of widths and heights and how many images in the dataset contains tables

# %%
print('Number of datapoints in ICDAR-2017 table extraction dataset : ', len(img_df))
# Out:
# Number of datapoints in ICDAR-2017 table extraction dataset :  36

# %%
width_list = [i[0] for i in img_df['image_dim'].values]
height_list = [i[1] for i in img_df['image_dim'].values]

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.hist(width_list)
plt.title('width dist. of images')
plt.subplot(1,2,2)
plt.hist(height_list)
plt.title('height dist. of images')
plt.show()

# %% [markdown]
# * The dimension of the images in this dataset vary from 800 to 1400 in width and 1000 to 1400 in height
# * But dimension of most of the images are (1000, 1300)
#
# ### Discussions
#
# * We have seen two datasets for the task for table extraction. They are marmot and ICDAR 2017
# * The ICDAR 2017 contains annotations table level bounding boxes whereas Marmot has both table and column level annotations
# * There are 495 datapoints available in Marmot and 549 in ICDAR 2017
# * The dimension of an image in Marmot is (816, 1056)
# * The dimension of a typical image ICDAR 2017 is (1000, 1300)
# * We have converted the annotations of marmot_v1.0 into masked images of tables and used the marmot_extended to create column level masks
# * The transformed masks and their corresponding images are stored in a new folder along with a csv to keep track of the individuals image and their masks.
# * We done a similar task in case of ICDAR dataset i.e., converting mask and storing them in a new location along with a csv
# * Inspired from the TableNet paper we will use the marmot data to train. Since it has both table & column level mask, it will help to learn the structural form of a table better.
# * Once the we have obtained a trained model, we will use the ICDAR data to test our model performance.
#
#
# <hr>
#
# ## 2. Modeling
#
# In this section we will experiment with the TableNet architechture proposed by Paliwaal et. al. First we will create a tensorflow dataset object using the marmot data and then we define the actual model.
#
# ### * Data definition

# %%
# defining data directory
tr_data_dir = os.path.join('data', 'marmot_masked')
train_df = pd.read_csv(os.path.join(tr_data_dir, 'data.csv'))

# %%
tf.keras.backend.clear_session()
dataset = tf.data.Dataset.from_tensor_slices((train_df['image_path'].values, train_df['tablemask_path'].values, train_df['columnmask_path'].values))
print(dataset)
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None))>

# %%
[x for x in dataset]
# Out:
# [(<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2006_3.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2006_3.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2006_3.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2013_63.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2013_63.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2013_63.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2013_64.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2013_64.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2013_64.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2014_4.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2014_4.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2014_4.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2014_6.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2014_6.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2014_6.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2018_4.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2018_4.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2018_4.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2018_8.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2018_8.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2018_8.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2019_2.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2019_2.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2019_2.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2019_3.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2019_3.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2019_3.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2020_8.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2020_8.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2020_8.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2023_31.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2023_31.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2023_31.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2023_33.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2023_33.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2023_33.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2024_3.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2024_3.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2024_3.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2028_14.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2028_14.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2028_14.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2030_4.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2030_4.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2030_4.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2031_24.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2031_24.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2031_24.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2032_10.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2032_10.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2032_10.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2032_6.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2032_6.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2032_6.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2034_11.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2034_11.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2034_11.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2034_8.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2034_8.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2034_8.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2035_2.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2035_2.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2035_2.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2035_4.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2035_4.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2035_4.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.2036_17.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\table\\10.1.1.1.2036_17.png'>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.1.2036_17.png'>),
#  (<tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\images\\10.1.1.1.
>,
#   <tf.Tensor: shape=(), dtype=string, numpy=b'data\\marmot_masked\\masks\\column\\10.1.1.6.2248_9.png'>)]

# %%
# defining function for loading the images into memory
# it will also perform resizing and normalizing at the time of loading 
def _parse_function(image, mask, colmask):
    dim = (512,512)
    image_decoded = tf.io.decode_png(tf.io.read_file(image), channels=3)
    image = tf.cast(image_decoded, tf.float32)
    image = tf.image.resize(image, dim)
    image = tf.cast(image, tf.float32) / 255.0
    
    mask_decoded = tf.io.decode_png(tf.io.read_file(mask), channels=1)
    mask = tf.cast(mask_decoded, tf.float32)
    mask = tf.image.resize(mask, dim)
    mask = tf.cast(mask, tf.float32) / 255.0

    colmask_decoded = tf.io.decode_png(tf.io.read_file(colmask), channels=1)
    colmask = tf.cast(colmask_decoded, tf.float32)
    colmask = tf.image.resize(colmask, dim)
    colmask = tf.cast(colmask, tf.float32) / 255.0
    
    mask_dict = {'table': mask, 'column': colmask}
    
    print("mask_dict = " , mask_dict)

    return image, mask_dict

# %%
DATA_SIZE = len(dataset)
VAL_SIZE = 0.4

VAL_LENGTH = int(VAL_SIZE*DATA_SIZE)
TRAIN_LENGTH = int((1-VAL_SIZE) * DATA_SIZE)

BATCH_SIZE = 1
BUFFER_SIZE = TRAIN_LENGTH

VAL_BUFFER_SIZE = VAL_LENGTH

VALIDATION_STEPS = VAL_LENGTH // BATCH_SIZE

STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

print("DATA_SIZE = " ,DATA_SIZE," VAL_LENGTH = ",VAL_LENGTH ," TRAIN_LENGTH = " , TRAIN_LENGTH,
      " VALIDATION_STEPS = " , VALIDATION_STEPS," STEPS_PER_EPOCH = " , STEPS_PER_EPOCH)
# Out:
# DATA_SIZE =  97  VAL_LENGTH =  38  TRAIN_LENGTH =  58  VALIDATION_STEPS =  38  STEPS_PER_EPOCH =  58

# %%
train = dataset.take(TRAIN_LENGTH)
val = dataset.skip(TRAIN_LENGTH)
train = train.map(_parse_function)
val = val.map(_parse_function)
# Out:
# mask_dict =  {'table': <tf.Tensor 'truediv_1:0' shape=(512, 512, 1) dtype=float32>, 'column': <tf.Tensor 'truediv_2:0' shape=(512, 512, 1) dtype=float32>}
# mask_dict =  {'table': <tf.Tensor 'truediv_1:0' shape=(512, 512, 1) dtype=float32>, 'column': <tf.Tensor 'truediv_2:0' shape=(512, 512, 1) dtype=float32>}

# %%
train_dataset = train.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = val.shuffle(VAL_BUFFER_SIZE).batch(BATCH_SIZE)
print("train_dataset = " ,train_dataset," val_dataset = ",val_dataset)
# Out:
# train_dataset =  <BatchDataset element_spec=(TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None), {'table': TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None), 'column': TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None)})>  val_dataset =  <BatchDataset element_spec=(TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None), {'table': TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None), 'column': TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None)})>

# %% [markdown]
# Lets check how a typical datapoint looks like

# %%
# function to display a list of images
def visualize(image_list):
  plt.figure(figsize=(15, 15))
  title = ['Input Image', 'Table Mask', 'Column Mask']
  for i in range(len(image_list)):
    plt.subplot(1, len(image_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(image_list[i]))
    plt.axis('off')
    plt.show()

# %%
for image, mask  in train.take(7):
  # print(mask.shape)
  visualize([image, mask['table'], mask['column']])

# %% [markdown]
# ### * Model definition

# %%
class TableConvLayer(Layer):
    def __init__(self, name='table'):
        super().__init__(name=name)
        self.conv7 = Conv2D(512, (1,1), activation='relu', name='conv7table')
        self.upsample_conv7 = UpSampling2D((2,2))
        self.concat_p4 = Concatenate()
        self.upsample_p4 = UpSampling2D((2,2))

        self.concat_p3 = Concatenate()
        self.upsample_p3 = UpSampling2D((2,2))

        self.upsample_p3_2 = UpSampling2D((2,2))
        self.convtranspose = Conv2DTranspose(3, (3,3), strides=2, padding='same')

    def call(self, inputs):
        X, pool3, pool4 = inputs
        X = self.conv7(X)
        X = self.upsample_conv7(X)
        X = self.concat_p4([X, pool4])
        X = self.upsample_p4(X)
        X = self.concat_p3([X, pool3])
        X = self.upsample_p3(X)
        X = self.upsample_p3_2(X)
        X = self.convtranspose(X)

        return X


class ColumnConvLayer(Layer):
    def __init__(self, name='column'):
        super().__init__(name=name)
        self.conv7 = Conv2D(512, (1,1), activation='relu', name='conv7column')
        self.dropout = Dropout(0.8)
        self.conv8 = Conv2D(512, (1,1), activation='relu', name='conv8column')
        self.upsample_conv8 = UpSampling2D((2,2))
        self.concat_p4 = Concatenate()
        self.upsample_p4 = UpSampling2D((2,2))

        self.concat_p3 = Concatenate()
        self.upsample_p3 = UpSampling2D((2,2))

        self.upsample_p3_2 = UpSampling2D((2,2))
        self.convtranspose = Conv2DTranspose(3, (3,3), strides=2, padding='same')

    def call(self, inputs):
        X, pool3, pool4 = inputs
        X = self.conv7(X)
        X = self.dropout(X)
        X = self.conv8(X)
        X = self.upsample_conv8(X)
        X = self.concat_p4([X, pool4])
        X = self.upsample_p4(X)
        X = self.concat_p3([X, pool3])
        X = self.upsample_p3(X)
        X = self.upsample_p3_2(X)
        X = self.convtranspose(X)

        return X

# %%
def build_tablenet():
    tf.keras.backend.clear_session()
    input_shape = (512,512,3)

    base = VGG19(input_shape=input_shape, include_top=False, weights='imagenet')

    end_layers_list = ['block3_pool', 'block4_pool', 'block5_pool']
    end_layers = [base.get_layer(i).output for i in end_layers_list]

    X = Conv2D(512, (1,1), activation='relu', name='block6_conv1')(end_layers[-1])
    X = Dropout(0.8)(X)
    X = Conv2D(512, (1,1), activation='relu', name='block6_conv2')(X)
    X = Dropout(0.8)(X)
    
    table_branch = TableConvLayer()([X, end_layers[0], end_layers[1]])
    column_branch = ColumnConvLayer()([X, end_layers[0], end_layers[1]])

    model = Model(inputs=base.input, outputs=[table_branch, column_branch], name='TableNetVGG19')
    return model

# %%
model = build_tablenet()
tf.keras.utils.plot_model(model,show_shapes=True,show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model.summary()
# Out:
# Model: "TableNetVGG19"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 512, 512, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 256, 256, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 256, 256, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 256, 256, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 128, 128, 12  0           ['block2_conv2[0][0]']
#                                 8)
#
#  block3_conv1 (Conv2D)          (None, 128, 128, 25  295168      ['block2_pool[0][0]']
#                                 6)
#
#  block3_conv2 (Conv2D)          (None, 128, 128, 25  590080      ['block3_conv1[0][0]']
#                                 6)
#
#  block3_conv3 (Conv2D)          (None, 128, 128, 25  590080      ['block3_conv2[0][0]']
#                                 6)
#
#  block3_conv4 (Conv2D)          (None, 128, 128, 25  590080      ['block3_conv3[0][0]']
#                                 6)
#
#  block3_pool (MaxPooling2D)     (None, 64, 64, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 64, 64, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 64, 64, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 64, 64, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 64, 64, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 32, 32, 512)  0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 32, 32, 512)  2359808     ['block5_conv3[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 16, 16, 512)  0           ['block5_conv4[0][0]']
#
#  block6_conv1 (Conv2D)          (None, 16, 16, 512)  262656      ['block5_pool[0][0]']
#
#  dropout (Dropout)              (None, 16, 16, 512)  0           ['block6_conv1[0][0]']
#
#  block6_conv2 (Conv2D)          (None, 16, 16, 512)  262656      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 16, 16, 512)  0           ['block6_conv2[0][0]']
#
#  table (TableConvLayer)         (None, 512, 512, 3)  297219      ['dropout_1[0][0]',
#                                                                   'block3_pool[0][0]',
#                                                                   'block4_pool[0][0]']
#
#  column (ColumnConvLayer)       (None, 512, 512, 3)  559875      ['dropout_1[0][0]',
#                                                                   'block3_pool[0][0]',
#                                                                   'block4_pool[0][0]']
#
# ==================================================================================================
# Total params: 21,406,790
# Trainable params: 21,406,790
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### * Callback definition and model compilation

# %%
# Ref: https://www.pyimagesearch.com/2018/06/04/keras-multiple-outputs-and-multiple-losses/


losses = {
    "table": tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    "column": tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
}

lossWeights = {"table": 1.0, "column": 1.0}
optim = tf.keras.optimizers.Adam(learning_rate=0.0001, epsilon=1e-08)
sc_acc = tf.keras.metrics.SparseCategoricalAccuracy(name='sc_accuracy')


model.compile(optimizer = optim,
              loss = losses,
              metrics = [sc_acc],
              loss_weights = lossWeights)

# %%
# visualizing initial predictions (without training)
def render(mask):
  mask = tf.argmax(mask, axis=-1)
  mask = mask[..., tf.newaxis]
  return mask[0]

# %%
for image, masks in val_dataset.take(1):
    table_mask, column_mask = masks['table'], masks['column']

pred_tab_mask, pred_col_mask = model.predict(image)
visualize([image[0], render(pred_tab_mask), render(pred_col_mask)])

# %%
# defining model callbacks (checkpoint and tensorboard)
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

checkpoint_path = "tablenet_weights/cp_{epoch:04d}_{val_loss:.4f}.ckpt" 
checkpoint_dir = os.path.dirname(checkpoint_path)

log_dir = "tablenet_logs"

if not os.path.exists(checkpoint_dir):
  os.makedirs(checkpoint_dir)
if not os.path.exists(log_dir):
  os.makedirs(log_dir)

cp_callback = ModelCheckpoint(checkpoint_path, verbose=1, save_best_only=True, monitor='val_loss', save_weights_only=True)

tb_callback = TensorBoard(log_dir)


callbacks = [cp_callback, tb_callback]

# %% [markdown]
# ### * Model training

# %%
model.fit(
    train_dataset, epochs=100,
    steps_per_epoch= STEPS_PER_EPOCH,
    validation_data=val_dataset,
    validation_steps= VALIDATION_STEPS,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
100
# 58/58 [==============================] - ETA: 0s - loss: 0.0566 - table_loss: 0.0180 - column_loss: 0.0386 - table_sc_accuracy: 0.9904 - column_sc_accuracy: 0.9803
# Epoch 96: val_loss did not improve from 0.32556
# 58/58 [==============================] - 418s 7s/step - loss: 0.0566 - table_loss: 0.0180 - column_loss: 0.0386 - table_sc_accuracy: 0.9904 - column_sc_accuracy: 0.9803 - val_loss: 0.5111 - val_table_loss: 0.3035 - val_column_loss: 0.2076 - val_table_sc_accuracy: 0.9253 - val_column_sc_accuracy: 0.9231
# Epoch 97/100
# 58/58 [==============================] - ETA: 0s - loss: 0.0546 - table_loss: 0.0178 - column_loss: 0.0368 - table_sc_accuracy: 0.9906 - column_sc_accuracy: 0.9810
# Epoch 97: val_loss did not improve from 0.32556
# 58/58 [==============================] - 415s 7s/step - loss: 0.0546 - table_loss: 0.0178 - column_loss: 0.0368 - table_sc_accuracy: 0.9906 - column_sc_accuracy: 0.9810 - val_loss: 0.5449 - val_table_loss: 0.3248 - val_column_loss: 0.2201 - val_table_sc_accuracy: 0.9277 - val_column_sc_accuracy: 0.9247
# Epoch 98/100
# 58/58 [==============================] - ETA: 0s - loss: 0.5326 - table_loss: 0.2931 - column_loss: 0.2396 - table_sc_accuracy: 0.8977 - column_sc_accuracy: 0.9085
# Epoch 98: val_loss did not improve from 0.32556
# 58/58 [==============================] - 389s 7s/step - loss: 0.5326 - table_loss: 0.2931 - column_loss: 0.2396 - table_sc_accuracy: 0.8977 - column_sc_accuracy: 0.9085 - val_loss: 0.8510 - val_table_loss: 0.3937 - val_column_loss: 0.4573 - val_table_sc_accuracy: 0.8535 - val_column_sc_accuracy: 0.8269
# Epoch 99/100
# 58/58 [==============================] - ETA: 0s - loss: 0.3569 - table_loss: 0.1893 - column_loss: 0.1676 - table_sc_accuracy: 0.9250 - column_sc_accuracy: 0.9262
# Epoch 99: val_loss did not improve from 0.32556
# 58/58 [==============================] - 389s 7s/step - loss: 0.3569 - table_loss: 0.1893 - column_loss: 0.1676 - table_sc_accuracy: 0.9250 - column_sc_accuracy: 0.9262 - val_loss: 0.6183 - val_table_loss: 0.3253 - val_column_loss: 0.2930 - val_table_sc_accuracy: 0.8992 - val_column_sc_accuracy: 0.9150
# Epoch 100/100
# 58/58 [==============================] - ETA: 0s - loss: 0.2385 - table_loss: 0.1150 - column_loss: 0.1235 - table_sc_accuracy: 0.9561 - column_sc_accuracy: 0.9458
# Epoch 100: val_loss did not improve from 0.32556
# 58/58 [==============================] - 387s 7s/step - loss: 0.2385 - table_loss: 0.1150 - column_loss: 0.1235 - table_sc_accuracy: 0.9561 - column_sc_accuracy: 0.9458 - val_loss: 0.3481 - val_table_loss: 0.1782 - val_column_loss: 0.1699 - val_table_sc_accuracy: 0.9311 - val_column_sc_accuracy: 0.9388

# %% [markdown]
# ## 3. Extracting table
#
# In this section we will use our trained model to segment the table area and apply OCR on the segmented region to finally obtain the table in the given image.

# %%
# loading trained model
model = build_tablenet()
latest_cp = tf.train.latest_checkpoint(checkpoint_dir)
model.load_weights(latest_cp)

# %%
def extract_table(image_fname):
    image_orig = Image.open(image_fname)
    original_dim = image_orig.size
    image = image_orig.resize((512,512))
    np_image = np.asarray(image)/255.0
    tab_mask, _ = model.predict(np.expand_dims(np_image, axis=0))
    
    tab_mask = np.squeeze(render(tab_mask).numpy())

    tab_mask = Image.fromarray(np.uint8(tab_mask))
    tab_mask = tab_mask.resize(original_dim)

    tab_mask = np.array(tab_mask)

    kernel_erode = np.ones((20,20), np.uint8)
    kernel = np.ones((50,50), np.uint8)
    
    tab_mask =cv2.erode(tab_mask, kernel_erode, iterations=2)


    tab_mask = cv2.morphologyEx(tab_mask, cv2.MORPH_OPEN, kernel)
    tab_mask = cv2.morphologyEx(tab_mask, cv2.MORPH_CLOSE, kernel)

    image_orig = np.array(image_orig)
    masked = cv2.bitwise_and(image_orig, image_orig, mask=tab_mask)
    # Ref: https://stackoverflow.com/questions/62813546/how-do-i-crop-an-image-based-on-custom-mask-in-python
    # transparent cropp
    tmp = cv2.cvtColor(masked, cv2.COLOR_BGR2GRAY)
    _,alpha = cv2.threshold(tmp,0,255,cv2.THRESH_BINARY)
    b, g, r = cv2.split(masked)
    rgba = [b,g,r, alpha]
    masked = cv2.merge(rgba,4)
    text = pytesseract.image_to_string(masked)
    print(text)
    plt.figure(figsize=(15,20))
    plt.axis('off')
    plt.imshow(masked)
    plt.show()

# %% [markdown]
# ### Testing on a sample datapoint from ICDAR 2017

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
images = os.listdir(os.path.join('data', 'ICDAR 2017', 'table_images'))
r = np.random.randint(len(images))
img_fname = os.path.join('data', 'ICDAR 2017', 'table_images', images[r])
print(img_fname)
extract_table(img_fname)
# Out:
# data\ICDAR 2017\table_images\POD_0051.png
# Yahio 2-009, Datuy Seasler Mout (Part 2 af Zh
#
# - ; | Strathe 8x {laa
# Header umber | Sekemaile Signal Name Pia Marmber
# 3 D_HEDI7 B26
# 2 D_HEDIa AB2S
# F} D_HEDI9 AD32
# ure 2-8 shows the debug heeder’s schernatic.
# 2-8 Badug Naavtar {99} Schassatie
# a
# DHFR 4
# 2 AED: 3 43 yes
# DHE 5 g 3 aFDS:
# DAF 7 gE
# 5 Debug >
# BE | Peue [ic 3 aFDs
# DAFDIO 41 4p FSH
# DUD? 13 122 AEDS
# DHF BIE is i6 DHFR:
# DAFDI6 17 19347
# DYFDIa 1s 20> 4FDIS
#
# CONN_PC3_10K?
#
# ure 2-9 shows the debug hezder's bozrd lebels.
#
# oo Boh
#
# Ratu Meador (0! Samad Manet

# %% [markdown]
# ### Discussions
#
# * From the example above we can see that the area segmented by the model does not give a proper rectangular table.
# * It might be due to lack of considerable amount of training data.
# * Resizing the image to higher resolution could have improved performance, but this idea has been discarded due to low resource constraint
# * Text detection by the OCR module is not very precise. It can be improved if we could somehow make the text more distinguisable by applying image operations.
# * Moreover, if the tabular region was segmented properly, the text in proximity to the table borders could be predicted better.
#
# <br>
# <br>
# <hr>
